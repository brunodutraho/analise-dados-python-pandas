# %%
import json

# %%
dados_receitas = {
    "Receitas": [
        {
            "titulo": "Bolo de Chocolate",
            "tempo_preparo": "45 minutos",
            "porcoes": 8,
            "ingredientes": [
                {"ingredientes": "Farinha de Trigo", 'Quantidade': "2 xícaras"},
                {"ingredientes": "Açúcar", 'Quantidade': "1 xícaras"},
                {"ingredientes": "Ovos", 'Quantidade': "3 xícaras"},
                {"ingredientes": "Leite", 'Quantidade': "1 xícaras"},
                {"ingredientes": "Manteiga", 'Quantidade': "1/2 xícaras"}
            ],
        },
        {
            "titulo": "Salada Caesar",
            "tempo_preparo": "20 minutos",
            "porcoes": 4,
            "ingredientes": [
                {"ingredientes": "Alface romana", "quantidade": "1 cabeça"},
                {"ingredientes": "Croutons", "quantidade": "1 xícara"},
                {"ingredientes": "Queijo parmesão", "quantidade": "1/2 xícara"},
                {"ingredientes": "Molho caesar", "quantidade": "1/4 xícara"},
            ],
        },
        {
            "titulo": "Pasta ao Pesto",
            "tempo_preparo": "30 minutos",
            "porcoes": 2,
            "ingredientes": [
                {"ingredientes": "Massa", "quantidade": "200g"},
                {"ingredientes": "Manjericão fresco", "quantidade": "1/2 xícara"},
                {"ingredientes": "Azeite de olíva", "quantidade": "1/3 xícara"},
                {"ingredientes": "Nozes", "quantidade": "1/4 xícara"},
                {"ingredientes": "Queijo parmesão", "quantidade": "1/4 xícara"},
            ],
        }
    ]
}

# %%
with open("../dados/receitas.json", "w", encoding="utf-8") as file:
    json.dump(dados_receitas, file, ensure_ascii=False, indent=4)
